# %%
pip install quandl

# %%
import quandl
import pandas as pd
#retrieve Apple data
apple = quandl.get('WIKI/AAPL')
#Retireve MSFT Data
ms = quandl.get('WIKI/MSFT')

# %%
# %matplotlib inline
ms.head()
# Out:
#              Open   High   Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 1986-03-13  25.50  29.25  25.5  28.00  3582600.0          0.0          1.0
# 1986-03-14  28.00  29.50  28.0  29.00  1070000.0          0.0          1.0
# 1986-03-17  29.00  29.75  29.0  29.50   462400.0          0.0          1.0
# 1986-03-18  29.50  29.75  28.5  28.75   235300.0          0.0          1.0
# 1986-03-19  28.75  29.00  28.0  28.25   166300.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close   Adj. Volume
# Date
# 1986-03-13   0.058941   0.067609  0.058941    0.064720  1.031789e+09
# 1986-03-14   0.064720   0.068187  0.064720    0.067031  3.081600e+08
# 1986-03-17   0.067031   0.068765  0.067031    0.068187  1.331712e+08
# 1986-03-18   0.068187   0.068765  0.065876    0.066454  6.776640e+07
# 1986-03-19   0.066454   0.067031  0.064720    0.065298  4.789440e+07

# %%
ms['Adj. Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
ms.index
# Out:
# DatetimeIndex(['1986-03-13', '1986-03-14', '1986-03-17', '1986-03-18',
#                '1986-03-19', '1986-03-20', '1986-03-21', '1986-03-24',
#                '1986-03-25', '1986-03-26',
#                ...
#                '2018-03-14', '2018-03-15', '2018-03-16', '2018-03-19',
#                '2018-03-20', '2018-03-21', '2018-03-22', '2018-03-23',
#                '2018-03-26', '2018-03-27'],
#               dtype='datetime64[ns]', name='Date', length=8076, freq=None)

# %%
ms['2018']['Adj. Close'].plot()
# Out:
# C:\Users\vaibh\AppData\Local\Temp\ipykernel_23532\3435832096.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   ms['2018']['Adj. Close'].plot()
# <Axes: xlabel='Date'>

# %%
ms.loc['2018-01-01':'2018-03-31']['Adj. Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
ms_price =  ms[['Adj. Close']]
apple_price = apple[['Adj. Close']]
ms_price.rename(columns ={'Adj. Close':'MSFT'},inplace = True)
apple_price.rename(columns ={'Adj. Close':'APPL'},inplace = True)
# Out:
# C:\Users\vaibh\AppData\Local\Temp\ipykernel_23532\3209558632.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ms_price.rename(columns ={'Adj. Close':'MSFT'},inplace = True)
# C:\Users\vaibh\AppData\Local\Temp\ipykernel_23532\3209558632.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apple_price.rename(columns ={'Adj. Close':'APPL'},inplace = True)

# %%
both_stocks = ms_price.join(apple_price,how='inner')

# %%
both_stocks.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
both_stocks.loc['2017'].plot()
# Out:
# <Axes: xlabel='Date'>
